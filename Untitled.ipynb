# %%
import wiki

# %%
france_election_polling = wiki.get_poll_tables(wiki.get_page_html('Opinion polling French presidential election'))
france_election_polling[0: 10]
# Out:
# ['Poll source', 'Fieldwork date', 'Sample size', 'Abstention', 'Emmanuel MacronEM', 'Marine Le PenFN']
# ['Poll source', 'Fieldwork date', 'Sample size', 'Jean-Luc Mélenchon(19.58% in the first round)', 'Benoît Hamon(6.36% in the first round)', 'François Fillon(20.01% in the first round)', 'Macron', 'Le Pen', 'Abs.', 'Macron', 'Le Pen', 'Abs.', 'Macron', 'Le Pen', 'Abs.']
# ['Poll source', 'Fieldwork date', 'Sample size', 'Abstention', 'Emmanuel MacronEM', 'Marine Le PenFN']
# ['Pollsource', 'Fieldwork date', 'Samplesize', 'MacronEM', 'Le PenFN']
# ['Poll source', 'Fieldwork date', 'Sample size', 'Abstention', 'François FillonLR', 'Marine Le PenFN']
# ['Poll source', 'Fieldwork date', 'Sample size', 'Abstention', 'Emmanuel MacronEM', 'François FillonLR']
# ['Poll source', 'Fieldwork date', 'Sample size', 'Abstention', 'Jean-Luc MélenchonFI', 'Emmanuel MacronEM']
# ['Poll source', 'Fieldwork date', 'Sample size', 'Abstention', 'Jean-Luc MélenchonFI', 'François FillonLR']
# ...

# %%
uk_election_polling = wiki.get_poll_tables(wiki.get_page_html('Opinion polling united kingdom general election'))
# Out:
# ['Date(s)conducted', 'Polling organisation/client', 'Sample size', 'Con', 'Lab', 'Lib Dem', 'SNP', 'Plaid', 'UKIP', 'Green', 'Others', 'Lead']
# ['Date(s)conducted', 'Polling organisation/client', 'Sample size', 'Con', 'Lab', 'Lib Dem', 'SNP', 'Plaid', 'UKIP', 'Green', 'Others', 'Lead']
# ['Date(s)conducted', 'Polling organisation/client', 'Sample size', 'SNP', 'Con', 'Lab', 'Lib Dem', 'Green', 'UKIP', 'Others', 'Lead']
# ['Date(s)conducted', 'Polling organisation/client', 'Sample size', 'SNP', 'Con', 'Lab', 'Lib Dem', 'Green', 'UKIP', 'Others', 'Lead']
# ['Date(s)conducted', 'Polling organisation/client', 'Sample size', 'Lab', 'Con', 'Plaid', 'Lib Dem', 'UKIP', 'Green', 'Others', 'Lead']
# ['Date(s)conducted', 'Polling organisation/client', 'Sample size', 'DUP', 'SF', 'SDLP', 'UUP', 'Alliance', 'Others', 'Lead']
# ['Date(s)conducted', 'Polling organisation/client', 'Sample size', 'Lab', 'Con', 'Lib Dem', 'Green', 'UKIP', 'Others', 'Lead']
# ...

# %%
uk_election_polling[0:10]
# Out:
# [{'Date(s)conducted': '6-8 Feb',
#   'Polling organisation/client': 'Opinium/The Observer'},
#  {'Con': '40%',
#   'Date(s)conducted': '1920 Dec',
#   'Green': '0%',
#   'Lab': '42%',
#   'Lib Dem': '7%',
#   'Others': '2%',
#   'Plaid': '4%',
#   'Polling organisation/client': 'YouGov/The Times',
#   'SNP': '5%',
#   'Sample size': '1,610',
#   'UKIP': '1%'},
#  {'Con': '41%',
#   'Date(s)conducted': '1214 Dec',
#   'Green': '3%',
#   'Lab': '42%',
#   'Lead': '1%',
#   'Lib Dem': '7%',
#   'Others': '0%',
#   'Plaid': '0%',
#   'Polling organisation/client': 'ICM Research/Sun on Sunday',
#   'SNP': '3%',
#   'Sample size': '2,004',
#   'UKIP': '4%'},
#  {'Con': '39%',
#   'Date(s)conducted': '1214 Dec',
#   'Green': '2%',
#   'Lab': '41%',
#   'Lead': '2%',
#   'Lib Dem': '7%',
#   'Others': '1%',
#   'Plaid': '1%',
#   'Polling organisation/client': 'Opinium/Observer',
#   'SNP': '3%',
#   'Sample size': '2,005',
#   'UKIP': '6%'},
#  {'Con': '42%',
# ...
