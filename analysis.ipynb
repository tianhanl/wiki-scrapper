# %%
import pandas as pd

# %%
df = pd.read_json('cleaned_frech_presidential_election_polling.json')

# %%
df
# Out:
#              access_time                                              name  \
# 0    2018-02-18 22:21:25  cleaned_frech_presidential_election_polling.json
# 1    2018-02-18 22:21:25  cleaned_frech_presidential_election_polling.json
# 2    2018-02-18 22:21:25  cleaned_frech_presidential_election_polling.json
# 3    2018-02-18 22:21:25  cleaned_frech_presidential_election_polling.json
# 4    2018-02-18 22:21:25  cleaned_frech_presidential_election_polling.json
# 5    2018-02-18 22:21:25  cleaned_frech_presidential_election_polling.json
# 6    2018-02-18 22:21:25  cleaned_frech_presidential_election_polling.json
# 7    2018-02-18 22:21:25  cleaned_frech_presidential_election_polling.json
# 8    2018-02-18 22:21:25  cleaned_frech_presidential_election_polling.json
# 9    2018-02-18 22:21:25  cleaned_frech_presidential_election_polling.json
# 10   2018-02-18 22:21:25  cleaned_frech_presidential_election_polling.json
# ...

# %%
import wiki
tables = wiki.read_tables('cleaned_frech_presidential_election_polling.json')['polling_data']

# %%
df = pd.DataFrame(tables)

# %%
df['Marine Le Pen'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     355     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 356     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     357
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ...
